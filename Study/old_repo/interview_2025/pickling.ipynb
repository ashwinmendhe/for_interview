# %% [markdown]
# ## pickling and unpikling
#
# * pickle : process of converting python object into byte stream to store it in a file/database, maintain program state across sessions or transport data over the network.

# %%
print("yes")
# Out:
# yes

# %% [markdown]
# * sql data is in python dict or data form , which readed from pandas df , need to convert in pickle.pkl/serializer form (binary form).

# %%
import seaborn as sns

df = sns.load_dataset('tips')

# %%
! pip3 install seaboarn
# Out:
# /bin/bash: /home/ashwin/2025/study/interview_2025/.venv/bin/pip3: /home/ashwin/study/interview_2025/.venv/bin/python3.13: bad interpreter: Permission denied

# %% [markdown]
# ### Serialize process : python data type to bytes stream (binary format)

# %%
import pickle, pandas as pd
filename = 'pickle_file.pkl'
df= pd.read_csv("data.csv")
pickle.dump(df, open(filename,'wb'))

# %% [markdown]
# ### UnSerialize process : bytes stream (binary format) t python data type

# %%
import pickle, pandas as pd
filename = 'pickle_file.pkl'
# df= pd.read_csv("data.csv")
df=pickle.load(open(filename,'rb'))
df
# Out:
#    id          name department gender   salary joining_date  \
# 0   1      John Doe         IT      M  85000.0   2020-06-15
# 1   2    Mary Smith    Finance      F      NaN   2019-08-10
# 2   3  Alex Johnson         HR      M  70000.0   2021-02-01
# 3   4       Bob Lee         IT      M  80000.0   2022-03-20
# 4   5     Eve Adams  Marketing      F  78000.0   2020-11-05
# 5   6   Linda Perez    Finance      F  91000.0   2018-12-25
# 6   7    Tom Harris      Sales      M  67000.0   2021-09-10
# 7   8     Sara Khan        NaN      F  88000.0   2019-04-18
# 8   9   Chris Brown         HR      M  72000.0   2022-05-25
# 9  10    Nina Patel  Marketing      F  76000.0   2020-02-12
#
#    performance_score  is_active
# 0                4.3       True
# 1                4.8       True
# 2                3.9      False
# 3                NaN       True
# 4                4.6       True
# 5                4.9       True
# 6                3.7       True
# 7                4.2      False
# ...
