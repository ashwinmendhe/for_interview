# %%
print(1)
# Out:
# 1

# %%
## must watch  piyush garg
https://www.youtube.com/watch?v=lFeYU31TnQ8&list=PLinedj3B30sBlBWRox2V2tg9QJ2zr4M3o

# %%
## this alos watch
https://www.youtube.com/watch?v=_Ac7CTHOFMg&list=PL0zysOflRCek8kmc_jYl_6C7tpud7U2V_
