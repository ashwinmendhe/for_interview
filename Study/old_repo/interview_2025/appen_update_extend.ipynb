# %%
print(1)
# Out:
# 1

# %% [markdown]
# ## append

# %%
x = [1,2,3]
x.append([4, 4])
x
# Out:
# [1, 2, 3, [4, 4]]

# %% [markdown]
# ## extend

# %%
x = [1,2,3]
x.extend([4,4])
x
# Out:
# [1, 2, 3, 4, 4]

# %% [markdown]
# ## add and update

# %%
set1 = {10,20, 30}
set1.add(40)
set1
# Out:
# {10, 20, 30, 40}

# %%
set1 = {10,20, 30}
set1.add({40,40})
set1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 set1 = {10,20, 30}
# ----> 2 set1.add({40,40})
#       3 set1
#
# TypeError: unhashable type: 'set'

# %%
# update
set1 = {10,20, 30}
set1.update({50,40})
set1
# Out:
# {10, 20, 30, 40, 50}
