# %%
print("y")
# Out:
# y

# %%
informational response (100-199)
successfull response (200-299)
redirection message (300-399)
client error message (400-499)
server error message (500-499)


in successful
201 created
202 accepted
203 no authoritive info
204 no content
205 reset content


in client error(400-499)
400 bad request
401 Unauthorised
402 Payment request
403 forbidden
404 not found (no route exist)
405 method not allowed
406 Not acceptable
407 proxy authantication required


in server side (500-599)

500 internal server error
501 Not implemented (any method curd)
502 bad gateway
503 service unavailable


redirection 300-399
user can redirect to other url
# Out:
#   Cell In[2], line 1
#     informational response (100-199)
#                   ^
# SyntaxError: invalid syntax
