# %% [markdown]
# ## overloading

# %% [markdown]
# * Same method but different task can be perform

# %%
class MyClass:
    def sum(self,a=None, b=None, c=None):
        if a!=None and b!=None and c !=None:
            s = a+b+c
        elif a!=None and b!=None:
            s = a*b
        else:
            s = "two no, reqired"
        return s

obj = MyClass()
print(obj.sum(1,2,3))
print(obj.sum(5,6))
# Out:
# 6
# 30

# %% [markdown]
# ## Overriding : here inheritence also use
# * if we write same method in both classes , parent and child class then the parent class method is not avilable to the child class.
# * in this case child case method is accisible which means child class methos is replacing parent class method
# * method overriding is used when programmer wants to modify exisisting behaviour of method.

# %%
class Add:
    def result(self, a,b):
        print(f"Addition : {a+b}")


class Multi(Add):
    def result(self, a,b):
        print(f"Multiplication : {a*b}")

a = Add()
m = Multi()
a.result(10,20)
m.result(10,20)
# Out:
# Addition : 30
# Multiplication : 200

# %%
class Add:
    def result(self, a,b):
        print(f"Addition : {a+b}")


class Multi(Add):
    def result(self, a,b):
        pass

a = Add()
m = Multi()
a.result(10,20)
m.result(10,20)
# Out:
# Addition : 30

# %% [markdown]
# ## Method with super() method

# %%
class Add:
    def result(self, x,y):
        print(f"Addition : {x+y}")


class Multi(Add):
    def result(self, a,b):
        super().result(a, b)
        print(f"Multipication : {a*b}")


# a = Add()
m = Multi()
# a.result(10,20)
m.result(10,20)
# Out:
# Addition : 30
# Multipication : 200
