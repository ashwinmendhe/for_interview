# %% [markdown]
# ## learing for tough que

# %%
a = 10
b = 3.14
c = "python"
print(type(a), type(b), type(c))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %%
a,b= 5,10
a,b = b,a
print(a,b)
# Out:
# 10 5

# %%
nums = [1,2,3,4,5,6]

for n in nums:
    if n%2 !=0:
        print(n, "odd")
    else:
        print(n, "even")
# Out:
# 1 odd
# 2 even
# 3 odd
# 4 even
# 5 odd
# 6 even

# %%
a, b = (5,10)
print(a,b)
# Out:
# 5 10

# %%
# Q2. Convert list of tuples [(1,2), (3,4)] into two lists [1,3] and [2,4].

pairs=[(1,2), (3,4)]
a,b = zip(*pairs)
print(list(a), list(b))
# Out:
# [1, 3] [2, 4]

# %%
s= [i*i for i in range(10) if i%2==0]
print(s)
# Out:
# [0, 4, 16, 36, 64]

# %%
data = [(1,2), (3,2), (5,4)]
for cur, nxt in zip(data, data[1:]):
    # print(cur)
    print(cur, "==", nxt, "?", cur==nxt)
# Out:
# (1, 2) == (3, 2) ? False
# (3, 2) == (5, 4) ? False

# %%
data = [(1,2), (5,2), (6,5), (1,0), (8,2)]
data.sort(key=lambda x:x[0])
print(data)
# Out:
# [(1, 2), (1, 0), (5, 2), (6, 5), (8, 2)]

# %%
def double(x):
    return x*2
print(double(5))
# Out:
# 10

# %%
double = lambda x:x*2
print(lambda x:x*2)
# Out:
# <function <lambda> at 0x75e53464ab60>

# %%
cube = lambda x: x*x*x
print(cube(5))
# Out:
# 125

# %%
avg = lambda x,y,z: (x+y+z)/3
print(avg(3,6,9))
# Out:
# 6.0

# %%
def app(fx, value):
    return 6 + fx(value)

val = app(lambda c: c*c*c, 2)
print(val)
# Out:
# 14

# %%
data = [(1,5), (2,9),(3,7)]
# val = max(data, key=lambda x:x[1])
data.sort(key=lambda x:x[1])
print(data)
# Out:
# [(1, 5), (3, 7), (2, 9)]

# %%
data = ['a', 'b', 'c']

for i ,val in enumerate(data):
    print(i,val)
# Out:
# 0 a
# 1 b
# 2 c

# %%
a = [1,2,3]
b = [6,4,5]
print(list(zip([1,2,3],[4,5,6])))
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %%
data = [(1,2), (3,4), (5,6), (1,2)]
# print(data.count(data))
# print(set(data))
duplicate = [t for t in set(data) if data.count(t)>1]
print(duplicate)
# Out:
# [(1, 2)]

# %%
data = [(1,2), (3,4), (5,6), (1,2)]

for (a,b) , (x,y) in zip(data, data[1:]):
    if b !=y:
        print(f"value changed from {b} to {y}")
# Out:
# value changed from 2 to 4
# value changed from 4 to 6
# value changed from 6 to 2

# %%
data = [(1,2), (3,4), (5,6), (1,2)]
unique = list(set(data))
print(unique)
# Out:
# [(1, 2), (3, 4), (5, 6)]

# %%
a = (1,2)
b = (3,7)
if a[1] >=b[0] and b[1] >=a[0]:
    print("overlap")

# %%
intervals = [(1,5), (4,7), (8,10), (9,12)]
for i in range(len(intervals)-1):
    a = intervals[i]
    b = intervals[i+1]
    if a[1]>b[0]:
        print(a,b , "yes")
# print(len(intervals))
# Out:
# (1, 5) (4, 7) yes
# (8, 10) (9, 12) yes

# %%
intervals = [(1,5), (4,7), (8,10), (9,12)]

print(intervals.sort())    
def merge(intervals):
    intervals.sort()
    merged = [intervals[0]]
    for cur in intervals[1:]:
        print(cur)
# Out:
# None
