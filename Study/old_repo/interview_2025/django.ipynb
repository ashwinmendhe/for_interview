# %% [markdown]
# 1️⃣ What is Django’s architecture?
# Django follows MTV (Model-Template-View) pattern.
#
# * Django is high leve

# %% [markdown]
# 3️⃣ Middleware

# %%
class SimpleMiddleware:
    def __init__(self, get_response):
        self.get_response = get_response
    def __call__(self, request):
        response = self.get_response(request)
        return response

# %%
4️⃣ Migrations

python manage.py makemigrations
python manage.py migrate
# Out:
#   Cell In[1], line 1
#     4️⃣ Migrations
#      ^
# SyntaxError: invalid character '️' (U+FE0F)

# %% [markdown]
# 5️⃣ Authentication
# Django has a built-in auth system with User model, login/logout views, and permissions.

# %% [markdown]
# ## interview q and a

# %%
pip install django
python -m django --version 
5.2.5

Django==5.2.5
django-filter==25.1
djangorestframework==3.16.1
# Out:
#   Cell In[1], line 1
#     pip install django
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# 1. for creating project and start app

# %%
django-admin startproject myproject .
python3 manage.py startapp myapp
python3 manage.py runserver

python3 manage.py makemigrations
python3 manage.py migrate

## if we have name to specific sql db
python3 manage.py migrate --database=users_db
python3 manage.py sqlmigrate app_name migration_name
python3 manage.py sqlmigrate myapp 0001_initial

## show all migration
python3 manange.py showmigrations
python3 manage.py showmigrations --list
python3 maanage.py showmigrations myapp

## create superuser
python3 manage.py createsuperuser


## Command to view a database schema of an existing database 
python3 manage.py inspectdb

##
# Out:
#   Cell In[2], line 1
#     django-admin startproject myproject .
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## ORM
