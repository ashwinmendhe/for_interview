# %%
import re
text = """Note 1 - Overview
A paragram is a pun created by altering a word or phrase, often by changing a letter for humorous 
or ironic effect. The term comes from Greek roots meaning "joke by letter". For example, 
"Swan Lake" could become "Swine Lake" in a 
Note 20 - star
story about pigs. The word "paragram" 9993337777 also refers to various companies, products, or 
services, such as 3D product viewers, a design agency, and a sales recruiting firm
Note 3 - start - (999)-333-7777
end"""

# pattern = r"Note \d - ([^\n]+)"
pattern = r"\(\d{3}\)-\d{3}-\d{4}|\d{10}"

matchs = re.findall(pattern, text)
matchs
# Out:
# ['9993337777', '(999)-333-7777']

# %%
import re
text = """Note 1 - Overview
A paragram is a pun created by altering a word or phrase, often by changing a letter for humorous 
or ironic effect. The term comes from Greek roots meaning "joke by letter". For example, 
"Swan Lake" could become "Swine Lake" in a 
Note 2 - star
story about pigs. The word "paragram" 9993337777 also refers to various companies, products, or 
services, such as 3D product viewers, a design agency, and a sales recruiting firm
Note 3 - start - (999)-333-7777
Note 4 - nine
end"""


pattern = r"Note \d - ([^\n]*)"
matchs = re.findall(pattern, text)
matchs
# Out:
# ['Overview', 'star', 'start - (999)-333-7777', 'nine']

# %%
import re
text = """A paragram is a pun created by altering a word or phrase, often by changing a FY2020 Q1 was $4 letter for humorous or ironic effect. The term comes from Greek roots meaning "joke by letter". For example, "Swan Lake" could become "Swine Lake" in a 
i.e. fy2020 Q4 it was $3.76 billion story about pigs. The word "paragram" also refers to various companies, products, or services, such as 3D product viewers, a design agency, and a sales recruiting firm
Note 3 - start
end"""

pattern = r"FY\d{4} Q[1-4]"
matchs = re.findall(pattern, text)
matchs
# Out:
# ['FY2020 Q1']

# %%
import re
text = """A paragram is a pun created by altering a word or phrase, often by changing a FY2020 Q1 was $4 letter for humorous or ironic effect. The term comes from Greek roots meaning "joke by letter". For example, "Swan Lake" could become "Swine Lake" in a 
i.e. fy2020 Q4 it was $3.76 billion story about pigs. The word "paragram" also refers to various companies, products, or services, such as 3D product viewers, a design agency, and a sales recruiting firm
Note 3 - start
end"""

pattern = r"FY(\d{4} Q[1-4])"
matchs = re.findall(pattern, text, flags=re.IGNORECASE)
matchs
# Out:
# ['2020 Q1', '2020 Q4']

# %%
import re
text = """A paragram is a pun created by altering a word or phrase, often by changing a 
FY2020 Q1 was $40.2 letter for humorous or ironic effect. The term comes from Greek 
roots meaning "joke by letter". For example, "Swan Lake" could become "Swine Lake" in a 
i.e. fy2020 Q4 it was $3.76 billion story about pigs. The word "paragram" 
also refers to various companies, products, or services, such as 3D product viewers, 
a design agency, and a sales recruiting firm
Note 3 - start
end"""

pattern = r"\$([\d\.]+)"
matchs = re.findall(pattern, text, flags=re.IGNORECASE)
matchs
# Out:
# ['40.2', '3.76']

# %%
import re
text = """A paragram is a pun created by altering a word or phrase, often by changing a 
FY2020 Q1 was $40.2 letter for humorous or ironic effect. The term comes from Greek 
roots meaning "joke by letter". For example, "Swan Lake" could become "Swine Lake" in a 
i.e. fy2020 Q4 it was $3.76 billion story about pigs. The word "paragram" 
also refers to various companies, products, or services, such as 3D product viewers, 
a design agency, and a sales recruiting firm
Note 3 - start
end"""

pattern = r"FY(\d{4} Q[1-4])[^\n]+\$([0-9\.]+)"
matchs = re.findall(pattern, text, flags=re.IGNORECASE)
matchs
# Out:
# [('2020 Q1', '40.2'), ('2020 Q4', '3.76')]
